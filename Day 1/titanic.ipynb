# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# %%
# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv(r'titanic.csv')

# %%
# Which features are available in the data set
print(train_df.columns.values)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %%
# preview the first 10 rows in the data set
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# preview the last 10 rows in the data set
train_df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
# preview the column , non-null rows and type of the columns in the dataset
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
# Used to view some basic statistical details like percentile, mean, std etc. of a data frame
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
# Checking the null vlaues

train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#Check the data types in the data frame
train_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# sorting data values according to particular column
train_df.sort_values("Fare")
# Out:
#      PassengerId  Survived  Pclass  \
# 266         1158         0       1
# 372         1264         0       1
# 21           913         0       3
# 133         1025         0       3
# 116         1008         0       3
# ..           ...       ...     ...
# 59           951         1       1
# 53           945         1       1
# 69           961         1       1
# 343         1235         1       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 266              Chisholm, Mr. Roderick Robert Crispin    male   NaN      0
# 372                            Ismay, Mr. Joseph Bruce    male  49.0      0
# 21                           Olsen, Master. Artur Karl    male   9.0      0
# 133                              Thomas, Mr. Charles P    male   NaN      1
# 116                                   Thomas, Mr. John    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Viewing first 10 rows after sorting (Descending)
train_df.sort_values("Fare", ascending = False).head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 53           945         1       1
# 69           961         1       1
# 24           916         1       1
# 142         1034         0       1
# 59           951         1       1
# 64           956         0       1
# 375         1267         1       1
# 184         1076         1       1
# 202         1094         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# 59                         Chaudanson, Miss. Victorine  female  36.0      0
# ...

# %%
#Saving sorted version of the data frame WAY 1
train_df = train_df.sort_values("Fare", ascending = False)
print(train_df)
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 53           945         1       1
# 69           961         1       1
# 24           916         1       1
# 142         1034         0       1
# ..           ...       ...     ...
# 133         1025         0       3
# 21           913         0       3
# 266         1158         0       1
# 372         1264         0       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Saving sorted version of the data frame WAY 2
train_df.sort_values("Fare", ascending = False, inplace = True)
print(train_df)
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 69           961         1       1
# 53           945         1       1
# 24           916         1       1
# 142         1034         0       1
# ..           ...       ...     ...
# 133         1025         0       3
# 21           913         0       3
# 266         1158         0       1
# 372         1264         0       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Sorting columns with strings which has NAN and to be listed towards end
train_df.sort_values("Cabin", ascending = True, na_position ='last')
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 208         1100         1       1          Rosenbaum, Miss. Edith Louise
# 331         1223         0       1           Dulles, Mr. William Crothers
# 28           920         0       1                Brady, Mr. John Bertram
# 112         1004         1       1               Evans, Miss. Edith Corse
# 374         1266         1       1  Dodge, Mrs. Washington (Ruth Vidaver)
# ..           ...       ...     ...                                    ...
# 116         1008         0       3                       Thomas, Mr. John
# 133         1025         0       3                  Thomas, Mr. Charles P
# 21           913         0       3              Olsen, Master. Artur Karl
# 266         1158         0       1  Chisholm, Mr. Roderick Robert Crispin
# 152         1044         0       3                     Storey, Mr. Thomas
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
train_df.sort_values("Cabin", ascending = True, na_position ='last').head(20)
train_df.sort_values("Cabin", ascending = True, na_position ='last').tail(20)
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 136         1028         0       3               Zakarian, Mr. Mapriededer
# 274         1166         0       3                   Saade, Mr. Jean Nassr
# 171         1063         0       3                     Zakarian, Mr. Ortin
# 332         1224         0       3                     Thomas, Mr. Tannous
# 237         1129         0       3                     Baccos, Mr. Raffull
# 27           919         0       3                       Daher, Mr. Shedid
# 19           911         1       3   Assaf Khalil, Mrs. Mariana (Miriam")"
# 17           909         0       3                       Assaf, Mr. Gerios
# 311         1203         0       3                    Vartanian, Mr. David
# 325         1217         0       3                          Assam, Mr. Ali
# 211         1103         0       3                       Finoli, Mr. Luigi
# ...

# %%
#Counting the occurences of variables
train_df["Sex"].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
#Count number of unique values that occur in dataset or in a column
train_df.nunique()
# Out:
# PassengerId    418
# Survived         2
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
#Count of Unique records for a particular column
train_df["Embarked"].nunique()
# Out:
# 3

# %%
#number of unique records for more than one column
train_df[["Embarked","Sex"]].nunique()
# Out:
# Embarked    3
# Sex         2
# dtype: int64

# %%
# Changing the datatypes of columns in data frame
print (train_df["Embarked"].dtype)
train_df["Embarked"] = train_df["Embarked"].astype("category")
print(train_df["Embarked"].dtype)
# Out:
# object
# category

# %%
#Flitering under ONE Condition
train_df["Embarked"] == "C"
# Out:
# 343     True
# 69     False
# 53     False
# 24      True
# 142     True
#        ...
# 133     True
# 21     False
# 266    False
# 372    False
# 152    False
# Name: Embarked, Length: 418, dtype: bool

# %%
#Changing all values in the embarked columns as 'C'
train_df["Embarked"]='C'
train_df["Embarked"].head(5)
# Out:
# 343    C
# 69     C
# 53     C
# 24     C
# 142    C
# Name: Embarked, dtype: object

# %%
#Want to see all information of those whose Embarked is C
train_df[train_df["Embarked"] == "C"]
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 69           961         1       1
# 53           945         1       1
# 24           916         1       1
# 142         1034         0       1
# ..           ...       ...     ...
# 133         1025         0       3
# 21           913         0       3
# 266         1158         0       1
# 372         1264         0       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Another way to see all information of those whose Embarked is C
embarked_c_mask = train_df["Embarked"] == "C"
train_df[embarked_c_mask]
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 69           961         1       1
# 53           945         1       1
# 24           916         1       1
# 142         1034         0       1
# ..           ...       ...     ...
# 133         1025         0       3
# 21           913         0       3
# 266         1158         0       1
# 372         1264         0       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#To see the data which are NOT having embarked as "C"
train_df[train_df["Embarked"] != "C"]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Flitering out using AND Condition
#we want to see the passengers whose Fare is smaller than 100 and who are female

train_df_fare_mask = train_df["Fare"] < 100
train_df_sex_mask = train_df["Sex"] == "female"
train_df[train_df_fare_mask & train_df_sex_mask]
# Out:
#      PassengerId  Survived  Pclass  \
# 411         1303         1       1
# 179         1071         1       1
# 150         1042         1       1
# 12           904         1       1
# 374         1266         1       1
# ..           ...       ...     ...
# 8            900         1       3
# 347         1239         1       3
# 19           911         1       3
# 1            893         1       3
# 291         1183         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 150              Earnshaw, Mrs. Boulton (Olive Potter)  female  23.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 374              Dodge, Mrs. Washington (Ruth Vidaver)  female  54.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Flitering out using OR Condition
# Find the passengers whose fare is more than 500 or older than 70.

train_df_fare_mask2 = train_df["Fare"] > 500
train_df_age_mask = train_df["Age"] > 70
train_df[train_df_fare_mask2 | train_df_age_mask]
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 96           988         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
#
#      Parch    Ticket      Fare        Cabin Embarked
# 343      1  PC 17755  512.3292  B51 B53 B55        C
# 96       0     19877   78.8500          C46        C

# %%
# IS NULL
# Show me the passengers whose cabin is unknown
null_mask = train_df["Cabin"].isnull()
train_df[null_mask]
# Out:
#      PassengerId  Survived  Pclass  \
# 375         1267         1       1
# 324         1216         1       1
# 217         1109         0       1
# 141         1033         1       1
# 327         1219         0       1
# ..           ...       ...     ...
# 116         1008         0       3
# 133         1025         0       3
# 21           913         0       3
# 266         1158         0       1
# 152         1044         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 375                     Bowen, Miss. Grace Scott  female  45.0      0      0
# 324                       Kreuchen, Miss. Emilie  female  39.0      0      0
# 217                     Wick, Mr. George Dennick    male  57.0      1      1
# 141                         Daniels, Miss. Sarah  female  33.0      0      0
# 327  Rosenshine, Mr. George (Mr George Thorne")"    male  46.0      0      0
# ...

# %%
# To count the null values of all columns in a dataframe
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Missing Values using heat map

train_df.isnull().sum()
sns.heatmap(train_df.isnull(), cbar = False).set_title("Missing values heatmap")
# Out:
# Text(0.5, 1, 'Missing values heatmap')

# %%
#Data Preprocessing Cabin

# we have to deal with Cabin (327), and Age (86). First I thought, we have to delete the ‘Cabin’ variable but then I found 
#something interesting. A cabin number looks like ‘C123’ and the letter refers to the deck. 
#Therefore we’re going to extract these and create a new feature, that contains a persons deck. 
#Afterwords we will convert the feature into a numeric variable. The missing values will be converted to zero. 
#In the picture below you can see the actual decks of the titanic, ranging from A to G.

import re
deck = {"A": 1, "B": 2, "C": 3, "D": 4, "E": 5, "F": 6, "G": 7, "U": 8}
data = [train_df]

# %%
for dataset in data:
    dataset['Cabin'] = dataset['Cabin'].fillna("U0")
    dataset['Deck'] = dataset['Cabin'].map(lambda x: re.compile("([a-zA-Z]+)").search(x).group())
    dataset['Deck'] = dataset['Deck'].map(deck)
    dataset['Deck'] = dataset['Deck'].fillna(0)
    dataset['Deck'] = dataset['Deck'].astype(int)

# %%
#To check whether deck column was added    
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 343 to 152
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        418 non-null    object
#  11  Embarked     418 non-null    object
#  12  Deck         418 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 45.7+ KB

# %%
# Now we can delete the cabin column as we donot need it further
# we can now drop the cabin feature
train_df = train_df.drop(['Cabin'], axis=1)

# %%
#To check whether cabin column was removed  
train_df.info() 
print(train_df['Deck'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 343 to 152
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Embarked     418 non-null    object
#  11  Deck         418 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 42.5+ KB
# 343    2
# 69     3
# 53     3
# 24     2
# 142    2
#       ..
# 133    8
# 21     8
# 266    8
# 372    2
# 152    8
# Name: Deck, Length: 418, dtype: int64

# %%
#Data Preprocessing Age

#Now we can tackle the issue with the age features missing values. I will create an array that contains 
#random numbers, which are computed based on the mean age value in regards to the standard deviation 
#and is_null

data = [train_df]

# %%
for dataset in data:
    mean = train_df["Age"].mean()
    std = train_df["Age"].std()
    is_null = dataset["Age"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_age = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in Age column with random values generated
    age_slice = dataset["Age"].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    dataset["Age"] = age_slice

# %%
#*********************************************************************************
#Check if there is any missing values
#*********************************************************************************
train_df.isnull().sum()
sns.heatmap(train_df.isnull(), cbar = False).set_title("Missing values heatmap")
# Out:
# Text(0.5, 1, 'Missing values heatmap')
